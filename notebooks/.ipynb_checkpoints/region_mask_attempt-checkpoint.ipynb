# %%
#Packages 
import numpy as np
import xarray as xr
import cmocean.cm as cmo
import matplotlib.pyplot as plt
import mpas_tools
from mpas_tools.planar_hex import make_planar_hex_mesh
from mpas_tools.mesh.conversion import convert, cull, mask
from mpas_tools.io import write_netcdf
from geometric_features import GeometricFeatures
from geometric_features import read_feature_collection

import xarray as xr
from geometric_features import read_feature_collection
from mpas_tools.mesh.mask import compute_mpas_region_masks
from mpas_tools.parallel import create_pool
from mpas_tools.io import write_netcdf

import json
import mosaic

# %% [markdown]
# ## In this NB, I copy BMM's work... (but like in a messier, less efficient way)
# Parts of this are copied from functions in the [basic_surface_wmt.py script for his wmt package](https://github.com/MPAS-Dev/MPAS-QuickViz/blob/8c78368d03a31d78923361ae6814c407fef3b045/ocean/AMOC/watermassanalysis/examples/basic_surface_wmt/basic_surface_wmt.py)

# %%
print(mpas_tools.__version__)
# Out:
# 1.2.2

# %%
# # create a geojson file (geojson.io)
# LS_test_gjson = {
#   "type": "FeatureCollection",
#   "features": [
#     {
#       "type": "Feature",
#       "properties": {
#         "name":"Labrador Sea... sort of",
#         "tags":"Labrador_Sea;Davis_Strait",
#         "object":"region",
#         "component":"ocean",
#         "author":"Kaila Uyeda"},
#       "geometry": {
#         "coordinates": [
#           [
#             [
#               -66.78654628714224,
#               67.04329908963595
#             ],
#             [
#               -64.10071681349476,
#               57.52316136748382
#             ],
#             [
#               -56.444059335337954,
#               52.23600877585457
#             ],
#             [
#               -44.02529898728204,
#               60.55350636692381
#             ],
#             [
#               -49.99073597744223,
#               67.80090427662248
#             ],
#             [
#               -66.78654628714224,
#               67.04329908963595
#             ]
#           ]
#         ],
#         "type": "Polygon"
#       }
#     }
#   ]
# }

# wmtnb_filepath = '/global/u2/k/kuyeda/WMT_NBs/'
# # save to a geojson file
# # with = open and then close
# # w = write mode

# with open(wmtnb_filepath+'LS_test.geojson','w') as f:
#     json.dump(LS_test_gjson, f, indent=2)

# print('file saved')

# %%
# bichan_filepath = '/pscratch/sd/k/kuyeda/bichan/mpaso/2km/'
# init = xr.open_dataset(bichan_filepath + '2km_channel_init.nc')
# cull = xr.open_dataset(bichan_filepath + '2km_channel_cull.nc')
# forcing = xr.open_dataset(bichan_filepath + '2km_channel_forcing.nc')
# base = xr.open_dataset(bichan_filepath + '2km_channel_base.nc')
# base

# %%
mesh_path = '/global/cfs/projectdirs/e3sm/inputdata/ocn/mpas-o/EC30to60E2r2/ocean.EC30to60E2r2.210210.nc'
mesh = xr.open_dataset(mesh_path)
dsMesh = mesh
dsMesh
# Out:
# <xarray.Dataset> Size: 1GB
# Dimensions:                        (nCells: 236853, nEdges: 719506,
#                                     nVertices: 482371, TWO: 2, maxEdges: 7,
#                                     maxEdges2: 14, vertexDegree: 3,
#                                     nVertLevels: 60, Time: 1,
#                                     nVertLevelsP1: 61, nForcingGroupsMax: 4)
# Dimensions without coordinates: nCells, nEdges, nVertices, TWO, maxEdges,
#                                 maxEdges2, vertexDegree, nVertLevels, Time,
#                                 nVertLevelsP1, nForcingGroupsMax
# Data variables: (12/73)
#     latCell                        (nCells) float64 2MB ...
#     lonCell                        (nCells) float64 2MB ...
#     xCell                          (nCells) float64 2MB ...
#     yCell                          (nCells) float64 2MB ...
#     zCell                          (nCells) float64 2MB ...
#     indexToCellID                  (nCells) int32 947kB ...
#     ...                             ...
#     accumulatedLandIceFrazilMass   (Time, nCells) float64 2MB ...
#     frazilSurfacePressure          (Time, nCells) float64 2MB ...
#     filteredSSHGradientZonal       (Time, nCells) float64 2MB ...
#     filteredSSHGradientMeridional  (Time, nCells) float64 2MB ...
#     forcingGroupNames              (Time, nForcingGroupsMax) |S64 256B ...
#     forcingGroupRestartTimes       (Time, nForcingGroupsMax) |S64 256B ...
# Attributes: (12/1163)
#     on_a_sphere:                                                   YES
#     sphere_radius:                                                 6371229.0
#     model_name:                                                    mpas
#     core_name:                                                     ocean
#     history:                                                       Thu Feb 11...
#     source:                                                        MPAS
#     ...                                                            ...
#     config_rx1_zstar_weight:                                       1.0
#     config_rx1_horiz_smooth_open_ocean_cells:                      20
#     config_rx1_min_levels:                                         3
#     config_rx1_min_layer_thickness:                                1.0
#     file_id:                                                       99ljfzad8z
#     NCO:                                                           netCDF Ope...

# %%
wmtnb_filepath = '/global/u2/k/kuyeda/WMT_NBs/'
fcMask = read_feature_collection(wmtnb_filepath + 'LS_test.geojson')
#pool = create_pool(process_count=8)
dsMasks = compute_mpas_region_masks(
    dsMesh, fcMask, maskTypes=('cell', 'vertex'), pool=pool
)

# %%
mask = xr.open_dataset(wmtnb_filepath + 'LS_test_masks.nc')
mask
# Out:
# <xarray.Dataset> Size: 3MB
# Dimensions:            (nCells: 236853, nRegions: 1, nVertices: 482371)
# Dimensions without coordinates: nCells, nRegions, nVertices
# Data variables:
#     regionCellMasks    (nCells, nRegions) int32 947kB ...
#     regionNames        (nRegions) |S64 64B ...
#     regionVertexMasks  (nVertices, nRegions) int32 2MB ...
# Attributes:
#     history:  Fri Aug 15 11:47:17 2025: /global/homes/k/kuyeda/.conda/envs/la...

# %% [markdown]
# ### plots of data variables from the mesh dataset

# %%
dvs_to_plot = ['fCell','temperature','salinity','temperatureSurfaceValue','salinitySurfaceValue','surfaceVelocityZonal','surfaceVelocityMeridional',
              'SSHGradientZonal','SSHGradientMeridional','normalVelocity']
# only normal velocity is found at the edges. all other variables are at cell centers

# select the time step and the surface vertical level (there is only one time step...)
dsMesh_t0s0 = dsMesh[dvs_to_plot].isel(Time=-1,nVertLevels=0)

# %%
# plot normal velos (not included in the for loop because it relies on lonEdge, latEdge instead of cell centers :/
fig,ax = plt.subplots(nrows=1,ncols=1,constrained_layout=True,figsize=(12,7))
ds = dsMesh_t0s0[dvs_to_plot[-1]]
im = ax.scatter(dsMesh.lonEdge, dsMesh.latEdge, c=ds, s=0.1, vmin=ds.min(),vmax=ds.max(), cmap=cmo.balance)
fig.colorbar(im, ax =ax, label= dvs_to_plot[-1] + ' (' + ds.units + ')')
ax.set_title(dvs_to_plot[-1] + ' t=0, z=0')

# save figs 
# fig_path = '/global/homes/k/kuyeda/WMT_NBs/initial_figs/'
# plt.savefig(fig_path + dvs_to_plot[-1] + '.png' , bbox_inches='tight')
# plt.close(fig)

# %%
fig_path = '/global/homes/k/kuyeda/WMT_NBs/initial_figs/'

for i in range(0,len(dvs_to_plot)-1): # all dvs excluding normal velocity
    fig,ax = plt.subplots(nrows=1,ncols=1,constrained_layout=True,figsize=(12,7))
    ds = dsMesh_t0s0[dvs_to_plot[i]]
    im = ax.scatter(dsMesh.lonCell, dsMesh.latCell, c=ds, s=0.1, vmin=ds.min(),vmax=ds.max(), cmap=cmo.balance)
    fig.colorbar(im, ax =ax, label= dvs_to_plot[i] + ' (' + ds.units + ')')
    ax.set_title(dvs_to_plot[i] + ' t=0, z=0')
    plt.savefig(fig_path + dvs_to_plot[i] + '.png' , bbox_inches='tight')
    plt.close(fig)

# %% [markdown]
# ### plot of mask from mesh data, masked with mask data

# %%
cellmasks = mask.regionCellMasks.isel(nRegions=0).astype(bool)
vertexmasks = mask.regionVertexMasks.isel(nRegions=0).astype(bool)
plt.figure(figsize=(16, 9))
plt.plot(
    mesh.lonCell[cellmasks]*360/(2*np.pi),
    mesh.latCell[cellmasks]*360/(2*np.pi),
    "o",
    markersize=2
)
plt.plot(
    mesh.lonEdge*360/(2*np.pi),
    mesh.latEdge*360/(2*np.pi),
    ".",
    markersize=1,
    color="C1"
)
plt.plot(
    mesh.lonVertex*360/(2*np.pi),
    mesh.latVertex*360/(2*np.pi),
    "+",
    markersize=2,
    color="C3"
)
plt.plot(
    mesh.lonVertex[vertexmasks]*360/(2*np.pi),
    mesh.latVertex[vertexmasks]*360/(2*np.pi),
    "+",
    markersize=4,
    color="C3"
)
plt.xlim(290, 315)
plt.ylim(51.5, 68)
# Out:
# (51.5, 68.0)

# %% [markdown]
# ### plots of data variables from simulations

# %%
bmm_filepath = '/pscratch/sd/b/bmoorema/run_001_062/'
ds = xr.open_dataset(bmm_filepath + '20210421_sim7_CORE_60to30E2r2.mpaso.hist.am.timeSeriesStatsMonthly.0063-09-01.nc')

prefix = 'timeMonthly_avg_'

# get the active tracers
active_tracers_keys = [i for i in ds.data_vars.keys() if i.startswith(prefix + 'active')]
active_tracers = ds[active_tracers_keys]
# active_tracers

# get the fluxes
# remove OceanRegion and maxGlobalStats and minGlobalStats
excluded_strings = ['avgValueWithinOceanLayerRegion','avgValueWithinOceanRegion','GlobalStats']

fluxes_keys = [
    i for i in ds.data_vars.keys() 
    if ('Flux' in i) and all(substring not in i for substring in excluded_strings)
]

fluxes = ds[fluxes_keys]
# fluxes

# get velocities
included_strings = ['Velocity','velocity']

velos_keys = [
    i for i in ds.data_vars.keys() 
    if any(substring in i for substring in included_strings) and all(substring not in i for substring in excluded_strings)
]

velos = ds[velos_keys]
# velos
# Out:
# /tmp/ipykernel_85403/229890530.py:2: FutureWarning: In a future version, xarray will not decode timedelta values based on the presence of a timedelta-like units attribute by default. Instead it will rely on the presence of a timedelta64 dtype attribute, which is now xarray's default way of encoding timedelta64 values. To continue decoding timedeltas based on the presence of a timedelta-like units attribute, users will need to explicitly opt-in by passing True or CFTimedeltaCoder(decode_via_units=True) to decode_timedelta. To silence this warning, set decode_timedelta to True, False, or a 'CFTimedeltaCoder' instance.
#   ds = xr.open_dataset(bmm_filepath + '20210421_sim7_CORE_60to30E2r2.mpaso.hist.am.timeSeriesStatsMonthly.0063-09-01.nc')

# %%
active_tracers_keys
# Out:
# ['timeMonthly_avg_activeTracerForcingMLTend_temperatureForcingMLTend',
#  'timeMonthly_avg_activeTracerForcingMLTend_salinityForcingMLTend',
#  'timeMonthly_avg_activeTracerHorMixMLTend_temperatureHorMixMLTend',
#  'timeMonthly_avg_activeTracerHorMixMLTend_salinityHorMixMLTend',
#  'timeMonthly_avg_activeTracerNonLocalMLTend_temperatureNonLocalMLTend',
#  'timeMonthly_avg_activeTracerNonLocalMLTend_salinityNonLocalMLTend',
#  'timeMonthly_avg_activeTracerVertAdvectionMLTend_temperatureVertAdvectionMLTend',
#  'timeMonthly_avg_activeTracerVertAdvectionMLTend_salinityVertAdvectionMLTend',
#  'timeMonthly_avg_activeTracerHorAdvectionMLTend_temperatureHorAdvectionMLTend',
#  'timeMonthly_avg_activeTracerHorAdvectionMLTend_salinityHorAdvectionMLTend',
#  'timeMonthly_avg_activeTracerVertMixMLTend_temperatureVertMixMLTend',
#  'timeMonthly_avg_activeTracerVertMixMLTend_salinityVertMixMLTend',
#  'timeMonthly_avg_activeTracersML_temperatureML',
#  'timeMonthly_avg_activeTracersML_salinityML',
#  'timeMonthly_avg_activeTracersTendML_temperatureTendML',
#  'timeMonthly_avg_activeTracersTendML_salinityTendML',
#  'timeMonthly_avg_activeTracersTend_temperatureTend',
#  'timeMonthly_avg_activeTracersTend_salinityTend',
#  'timeMonthly_avg_activeTracerHorizontalAdvectionTendency_temperatureHorizontalAdvectionTendency',
#  'timeMonthly_avg_activeTracerHorizontalAdvectionTendency_salinityHorizontalAdvectionTendency',
#  'timeMonthly_avg_activeTracerVerticalAdvectionTendency_temperatureVerticalAdvectionTendency',
#  'timeMonthly_avg_activeTracerVerticalAdvectionTendency_salinityVerticalAdvectionTendency',
#  'timeMonthly_avg_activeTracerVertMixTendency_temperatureVertMixTendency',
#  'timeMonthly_avg_activeTracerVertMixTendency_salinityVertMixTendency',
#  'timeMonthly_avg_activeTracerHorMixTendency_temperatureHorMixTendency',
#  'timeMonthly_avg_activeTracerHorMixTendency_salinityHorMixTendency',
#  'timeMonthly_avg_activeTracerSurfaceFluxTendency_temperatureSurfaceFluxTendency',
#  'timeMonthly_avg_activeTracerSurfaceFluxTendency_salinitySurfaceFluxTendency',
#  'timeMonthly_avg_activeTracerNonLocalTendency_temperatureNonLocalTendency',
#  'timeMonthly_avg_activeTracerNonLocalTendency_salinityNonLocalTendency',
#  'timeMonthly_avg_activeTracerVerticalAdvectionTopFlux_temperatureVerticalAdvectionTopFlux',
#  'timeMonthly_avg_activeTracerVerticalAdvectionTopFlux_salinityVerticalAdvectionTopFlux',
#  'timeMonthly_avg_activeTracerHorizontalAdvectionEdgeFlux_temperatureHorizontalAdvectionEdgeFlux',
#  'timeMonthly_avg_activeTracerHorizontalAdvectionEdgeFlux_salinityHorizontalAdvectionEdgeFlux',
#  'timeMonthly_avg_activeTracers_temperature',
#  'timeMonthly_avg_activeTracers_salinity',
#  'timeMonthly_avg_activeTracersSurfaceFlux_temperatureSurfaceFlux',
#  'timeMonthly_avg_activeTracersSurfaceFlux_salinitySurfaceFlux',
#  'timeMonthly_avg_activeTracersSurfaceFluxRunoff_temperatureSurfaceFluxRunoff',
#  'timeMonthly_avg_activeTracersSurfaceFluxRunoff_salinitySurfaceFluxRunoff',
#  'timeMonthly_avg_activeTracersSurfaceFluxRemoved_temperatureSurfaceFluxRemoved',
#  'timeMonthly_avg_activeTracersSurfaceFluxRemoved_salinitySurfaceFluxRemoved']

# %%
velos
# Out:
# <xarray.Dataset> Size: 2GB
# Dimensions:                                                                      (
#                                                                                   Time: 1,
#                                                                                   nCells: 236853,
#                                                                                   nVertLevels: 60,
#                                                                                   nEdges: 719506,
#                                                                                   nVertLevelsP1: 61,
#                                                                                   nOceanRegionsTmp: 7)
# Dimensions without coordinates: Time, nCells, nVertLevels, nEdges,
#                                 nVertLevelsP1, nOceanRegionsTmp
# Data variables: (12/21)
#     timeMonthly_avg_velocityMeridional                                           (Time, nCells, nVertLevels) float32 57MB ...
#     timeMonthly_avg_velocityZonal                                                (Time, nCells, nVertLevels) float32 57MB ...
#     timeMonthly_avg_normalVelocity                                               (Time, nEdges, nVertLevels) float32 173MB ...
#     timeMonthly_avg_vertVelocityTop                                              (Time, nCells, nVertLevelsP1) float32 58MB ...
#     timeMonthly_avg_normalGMBolusVelocity                                        (Time, nEdges, nVertLevels) float32 173MB ...
#     timeMonthly_avg_vertGMBolusVelocityTop                                       (Time, nCells, nVertLevelsP1) float32 58MB ...
#     ...                                                                           ...
#     timeMonthly_avg_velocityZonalTimesTemperature                                (Time, nCells, nVertLevels) float32 57MB ...
#     timeMonthly_avg_velocityMeridionalTimesTemperature                           (Time, nCells, nVertLevels) float32 57MB ...
#     timeMonthly_avg_normalVelocityTimesTemperature                               (Time, nEdges, nVertLevels) float32 173MB ...
#     timeMonthly_avg_avgValueWithinOceanVolumeRegion_avgVolumeVelocityZonal       (Time, nOceanRegionsTmp) float32 28B ...
#     timeMonthly_avg_avgValueWithinOceanVolumeRegion_avgVolumeVelocityMeridional  (Time, nOceanRegionsTmp) float32 28B ...
#     timeMonthly_avg_avgValueWithinOceanVolumeRegion_avgVolumeVertVelocityTop     (Time, nOceanRegionsTmp) float32 28B ...
# Attributes: (12/722)
#     on_a_sphere:                                                  YES
#     sphere_radius:                                                6.371229e+06
#     model_name:                                                   mpas
#     core_name:                                                    ocean
#     history:                                                      mpirun -n 6...
#     source:                                                       MPAS
#     ...                                                           ...
#     config_AM_harmonicAnalysis_use_K2:                            YES
#     config_AM_harmonicAnalysis_use_K1:                            YES
#     config_AM_harmonicAnalysis_use_O1:                            YES
#     config_AM_harmonicAnalysis_use_Q1:                            YES
#     config_AM_harmonicAnalysis_use_P1:                            YES
#     file_id:                                                      1r030sw98p

# %%
# velos[prefix + 'velocityMeridional'].isel(Time=0,nVertLevels=30)
plt.scatter(dsMesh.lonCell,dsMesh.latCell, c=velos[prefix + 'velocityMeridional'].isel(Time=0,nVertLevels=30))

# %%
velos.data_vars.keys()
# Out:
# KeysView(Data variables:
#     timeMonthly_avg_velocityMeridional                                           (Time, nCells, nVertLevels) float32 57MB ...
#     timeMonthly_avg_velocityZonal                                                (Time, nCells, nVertLevels) float32 57MB ...
#     timeMonthly_avg_normalVelocity                                               (Time, nEdges, nVertLevels) float32 173MB ...
#     timeMonthly_avg_vertVelocityTop                                              (Time, nCells, nVertLevelsP1) float32 58MB ...
#     timeMonthly_avg_normalGMBolusVelocity                                        (Time, nEdges, nVertLevels) float32 173MB ...
#     timeMonthly_avg_vertGMBolusVelocityTop                                       (Time, nCells, nVertLevelsP1) float32 58MB ...
#     timeMonthly_avg_GMBolusVelocityZonal                                         (Time, nCells, nVertLevels) float32 57MB ...
#     timeMonthly_avg_GMBolusVelocityMeridional                                    (Time, nCells, nVertLevels) float32 57MB ...
#     timeMonthly_avg_velocityZonalTimesTemperature_GM                             (Time, nCells, nVertLevels) float32 57MB ...
#     timeMonthly_avg_velocityMeridionalTimesTemperature_GM                        (Time, nCells, nVertLevels) float32 57MB ...
#     timeMonthly_avg_normalGMBolusVelocityTimesTemperature                        (Time, nEdges, nVertLevels) float32 173MB ...
#     timeMonthly_avg_normalGMBolusVelocitySquared                                 (Time, nEdges, nVertLevels) float32 173MB ...
#     timeMonthly_avg_velocityZonalSquared                                         (Time, nCells, nVertLevels) float32 57MB ...
#     timeMonthly_avg_velocityMeridionalSquared                                    (Time, nCells, nVertLevels) float32 57MB ...
#     timeMonthly_avg_normalVelocitySquared                                        (Time, nEdges, nVertLevels) float32 173MB ...
#     timeMonthly_avg_velocityZonalTimesTemperature                                (Time, nCells, nVertLevels) float32 57MB ...
#     timeMonthly_avg_velocityMeridionalTimesTemperature                           (Time, nCells, nVertLevels) float32 57MB ...
#     timeMonthly_avg_normalVelocityTimesTemperature                               (Time, nEdges, nVertLevels) float32 173MB ...
#     timeMonthly_avg_avgValueWithinOceanVolumeRegion_avgVolumeVelocityZonal       (Time, nOceanRegionsTmp) float32 28B ...
#     timeMonthly_avg_avgValueWithinOceanVolumeRegion_avgVolumeVelocityMeridional  (Time, nOceanRegionsTmp) float32 28B ...
#     timeMonthly_avg_avgValueWithinOceanVolumeRegion_avgVolumeVertVelocityTop     (Time, nOceanRegionsTmp) float32 28B ...)

# %% [markdown]
# At this point, we have a mesh file (dsMesh) with latcell, loncell, actual coordinates, ig, and we also have a mask (mask) to specify *where* we want to study (region).\
# So we want to label the mesh file with the region of study... \
# mask.regionCellMasks (nCells, nRegions) $\rightarrow$ dsMesh has nCells as a dimension... so we'd want to align them over where their ncells values are the same...

# %%
mesh
# Out:
# <xarray.Dataset> Size: 1GB
# Dimensions:                        (nCells: 236853, nEdges: 719506,
#                                     nVertices: 482371, TWO: 2, maxEdges: 7,
#                                     maxEdges2: 14, vertexDegree: 3,
#                                     nVertLevels: 60, Time: 1,
#                                     nVertLevelsP1: 61, nForcingGroupsMax: 4)
# Dimensions without coordinates: nCells, nEdges, nVertices, TWO, maxEdges,
#                                 maxEdges2, vertexDegree, nVertLevels, Time,
#                                 nVertLevelsP1, nForcingGroupsMax
# Data variables: (12/73)
#     latCell                        (nCells) float64 2MB 1.57 -0.4633 ... 0.1429
#     lonCell                        (nCells) float64 2MB 5.919 0.6299 ... 2.347
#     xCell                          (nCells) float64 2MB ...
#     yCell                          (nCells) float64 2MB ...
#     zCell                          (nCells) float64 2MB ...
#     indexToCellID                  (nCells) int32 947kB ...
#     ...                             ...
#     accumulatedLandIceFrazilMass   (Time, nCells) float64 2MB ...
#     frazilSurfacePressure          (Time, nCells) float64 2MB ...
#     filteredSSHGradientZonal       (Time, nCells) float64 2MB ...
#     filteredSSHGradientMeridional  (Time, nCells) float64 2MB ...
#     forcingGroupNames              (Time, nForcingGroupsMax) |S64 256B ...
#     forcingGroupRestartTimes       (Time, nForcingGroupsMax) |S64 256B ...
# Attributes: (12/1163)
#     on_a_sphere:                                                   YES
#     sphere_radius:                                                 6371229.0
#     model_name:                                                    mpas
#     core_name:                                                     ocean
#     history:                                                       Thu Feb 11...
#     source:                                                        MPAS
#     ...                                                            ...
#     config_rx1_zstar_weight:                                       1.0
#     config_rx1_horiz_smooth_open_ocean_cells:                      20
#     config_rx1_min_levels:                                         3
#     config_rx1_min_layer_thickness:                                1.0
#     file_id:                                                       99ljfzad8z
#     NCO:                                                           netCDF Ope...

# %%
# give mask regionCellMasks datavariable a regionNames coordinate
coord = mask.regionCellMasks
coord.coords['regionNames'] = mask.regionNames.astype(str)

# instead of nRegions as dimension, make regionNames dimension (string vs 0 or 1)
coord.swap_dims({'nRegions':'regionNames'})
coord_mask = coord

# %%
booled = coord_mask.astype(bool)

# %% [markdown]
# now restructure the coordinates for lats and lons to be in degrees

# %%
coord_latCell = np.rad2deg(mesh.latCell)
coord_lonCell = np.rad2deg(mesh.lonCell)
coord_areaCell = mesh.areaCell

# %%
# combine all the coordinates
coords = xr.merge([coord_mask, coord_latCell, coord_lonCell, coord_areaCell])
coords
# Out:
# <xarray.Dataset> Size: 7MB
# Dimensions:          (nRegions: 1, nCells: 236853)
# Coordinates:
#     regionNames      (nRegions) <U64 256B 'Labrador Sea... sort of'
# Dimensions without coordinates: nRegions, nCells
# Data variables:
#     regionCellMasks  (nCells, nRegions) int32 947kB ...
#     latCell          (nCells) float64 2MB 89.94 -26.55 -26.55 ... 25.55 8.189
#     lonCell          (nCells) float64 2MB 339.1 36.09 108.0 ... 238.5 134.5
#     areaCell         (nCells) float64 2MB ...

# %% [markdown]
# Here, he "builds and applies a subdomain". I don't know what that means.

# %%
# make the nCell dimension a coordinate
coords['nCells'] = coords.nCells
coords

# select a subdomain that is a box. It is bounded above and below by -100N and 40N and east and west by 0E and 85E.
subdomain = [
    coords.lonCell > -100,
    coords.lonCell < 40,
    coords.latCell > 0,
    coords.latCell < 85,]

subdomain = np.logical_and.reduce(subdomain)
coords = coords.isel(nCells=subdomain)

coords['regionCellMasks'] = coords.regionCellMasks.astype(bool)
coords
# Out:
# <xarray.Dataset> Size: 118kB
# Dimensions:          (nRegions: 1, nCells: 3573)
# Coordinates:
#     regionNames      (nRegions) <U64 256B 'Labrador Sea... sort of'
#   * nCells           (nCells) int64 29kB 36 5960 5961 ... 236609 236620 236802
# Dimensions without coordinates: nRegions
# Data variables:
#     regionCellMasks  (nCells, nRegions) bool 4kB False False ... False False
#     latCell          (nCells) float64 29kB 78.15 0.1367 0.2302 ... 79.05 0.4441
#     lonCell          (nCells) float64 29kB 13.3 8.065 7.812 ... 1.566 5.05 9.176
#     areaCell         (nCells) float64 29kB ...

# %% [markdown]
# <div class="alert alert-block alert-info">
# <b>Tip:</b> Stop.
# </div>

# %%
coords.areaCell.plot()

# %%
dsMesh = make_planar_hex_mesh(nx=10, ny=20, dc=1000., nonperiodic_x=True,
                              nonperiodic_y=False)
dsMesh = cull(dsMesh)
dsMesh = convert(dsMesh)
# Out:
# cullCell
# int32
# Running: MpasCellCuller.x /tmp/tmpdak7ssqk/ds_in.nc /tmp/tmpdak7ssqk/ds_out.nc
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[64], line 3
#       1 dsMesh = make_planar_hex_mesh(nx=10, ny=20, dc=1000., nonperiodic_x=True,
#       2                               nonperiodic_y=False)
# ----> 3 dsMesh = cull(dsMesh)
#       4 dsMesh = convert(dsMesh)
#
# File ~/.conda/envs/lanl_env/lib/python3.13/site-packages/mpas_tools/mesh/conversion.py:153, in cull(dsIn, dsMask, dsInverse, dsPreserve, graphInfoFileName, logger, dir)
#     149     graphInfoFileName = os.path.abspath(graphInfoFileName)
#     151 outDir = os.path.dirname(outFileName)
# --> 153 check_call(args=args, logger=logger)
#     155 dsOut = xr.open_dataset(outFileName)
#     156 dsOut.load()
#
# File ~/.conda/envs/lanl_env/lib/python3.13/site-packages/mpas_tools/logging.py:51, in check_call(args, logger, log_command, timeout, **kwargs)
#      48 if log_command:
#      49     logger.info(f'Running: {print_args}')
# ---> 51 process = subprocess.Popen(
#      52     args, stdout=subprocess.PIPE, stderr=subprocess.PIPE, **kwargs
#      53 )
#      54 stdout, stderr = process.communicate(timeout=timeout)
#      56 if stdout:
#
# File ~/.conda/envs/lanl_env/lib/python3.13/subprocess.py:1039, in Popen.__init__(self, args, bufsize, executable, stdin, stdout, stderr, preexec_fn, close_fds, shell, cwd, env, universal_newlines, startupinfo, creationflags, restore_signals, start_new_session, pass_fds, user, group, extra_groups, encoding, errors, text, umask, pipesize, process_group)
#    1035         if self.text_mode:
#    1036             self.stderr = io.TextIOWrapper(self.stderr,
#    1037                     encoding=encoding, errors=errors)
# -> 1039     self._execute_child(args, executable, preexec_fn, close_fds,
#    1040                         pass_fds, cwd, env,
#    1041                         startupinfo, creationflags, shell,
#    1042                         p2cread, p2cwrite,
#    1043                         c2pread, c2pwrite,
#    1044                         errread, errwrite,
#    1045                         restore_signals,
#    1046                         gid, gids, uid, umask,
#    1047                         start_new_session, process_group)
#    1048 except:
#    1049     # Cleanup if the child failed starting.
#    1050     for f in filter(None, (self.stdin, self.stdout, self.stderr)):
#
# File ~/.conda/envs/lanl_env/lib/python3.13/subprocess.py:1969, in Popen._execute_child(self, args, executable, preexec_fn, close_fds, pass_fds, cwd, env, startupinfo, creationflags, shell, p2cread, p2cwrite, c2pread, c2pwrite, errread, errwrite, restore_signals, gid, gids, uid, umask, start_new_session, process_group)
#    1967     err_msg = os.strerror(errno_num)
#    1968 if err_filename is not None:
# -> 1969     raise child_exception_type(errno_num, err_msg, err_filename)
#    1970 else:
#    1971     raise child_exception_type(errno_num, err_msg)
#
# FileNotFoundError: [Errno 2] No such file or directory: 'MpasCellCuller.x'

# %% [markdown]
# Created a base mesh and the converted it to an mpas mesh.
#
# activate environment with the ```mpas_tools``` mesh.\
# ``` conda activate lanl_env```
#
# create a base mesh \
# ```planar_hex --nx 4 --ny 4 --dc 10e3 -o base_mesh.nc```
#
# "convert to a spec-compliant format" named mesh.nc\
# ```MpasMeshConverter.x base_mesh.nc mesh.nc```

# %%
import xarray as xr
from geometric_features import read_feature_collection
from mpas_tools.mesh.mask import compute_mpas_region_masks
from mpas_tools.parallel import create_pool
from mpas_tools.io import write_netcdf


test_filepath = '/pscratch/sd/k/kuyeda/test_dir/'

dsMesh = xr.open_dataset(test_filepath + 'mesh.nc', decode_cf=False, decode_times=False)
fcMask = read_feature_collection('regions.geojson')
pool = create_pool(process_count=8)
dsMasks = compute_mpas_region_masks(
    dsMesh, fcMask, maskTypes=('cell', 'vertex'), pool=pool
)
write_netcdf(dsMasks, 'region_masks.nc')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[55], line 11
#       8 test_filepath = '/pscratch/sd/k/kuyeda/test_dir/'
#      10 dsMesh = xr.open_dataset(test_filepath + 'mesh.nc', decode_cf=False, decode_times=False)
# ---> 11 fcMask = read_feature_collection('regions.geojson')
#      12 pool = create_pool(process_count=8)
#      13 dsMasks = compute_mpas_region_masks(
#      14     dsMesh, fcMask, maskTypes=('cell', 'vertex'), pool=pool
#      15 )
#
# File ~/.conda/envs/lanl_env/lib/python3.13/site-packages/geometric_features/feature_collection.py:42, in read_feature_collection(fileName)
#      38 # Authors
#      39 # -------
#      40 # Xylar Asay-Davis
#      41 fc = FeatureCollection()
# ---> 42 with open(fileName) as f:
#      43     featuresDict = json.load(f)
#      44     for feature in featuresDict['features']:
#
# FileNotFoundError: [Errno 2] No such file or directory: 'regions.geojson'

# %%
test_filepath = '/pscratch/sd/k/kuyeda/test_dir/'
gf = GeometricFeatures()
fcLandCoverage = gf.read(
    componentName='natural_earth',
    objectType='region',
    featureNames=['Land Coverage']
)
dsBaseMesh = xr.open_dataset(test_filepath + 'base_mesh.nc')
dsLandMask = mask(dsBaseMesh, fcMask=fcLandCoverage)
dsCulledMesh = cull(dsBaseMesh, dsMask=dsLandMask)
write_netcdf(dsCulledMesh, test_filepath + 'culled_mesh.nc')
# Out:
# Running: compute_mpas_region_masks -m /tmp/tmpzerdext0/mesh_in.nc -o /tmp/tmpzerdext0/mask_out.nc -g /tmp/tmpzerdext0/mask.geojson -t cell --process_count 1 --format NETCDF3_64BIT
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[52], line 9
#       3 fcLandCoverage = gf.read(
#       4     componentName='natural_earth',
#       5     objectType='region',
#       6     featureNames=['Land Coverage']
#       7 )
#       8 dsBaseMesh = xr.open_dataset(test_filepath + 'base_mesh.nc')
# ----> 9 dsLandMask = mask(dsBaseMesh, fcMask=fcLandCoverage)
#      10 dsCulledMesh = cull(dsBaseMesh, dsMask=dsLandMask)
#      11 write_netcdf(dsCulledMesh, test_filepath + 'culled_mesh.nc')
#
# File ~/.conda/envs/lanl_env/lib/python3.13/site-packages/mpas_tools/mesh/conversion.py:214, in mask(dsMesh, fcMask, logger, dir, cores)
#     211 if mpas_tools.io.default_engine is not None:
#     212     args.extend(['--engine', mpas_tools.io.default_engine])
# --> 214 check_call(args=args, logger=logger)
#     216 dsOut = xr.open_dataset(outFileName)
#     217 dsOut.load()
#
# File ~/.conda/envs/lanl_env/lib/python3.13/site-packages/mpas_tools/logging.py:51, in check_call(args, logger, log_command, timeout, **kwargs)
#      48 if log_command:
#      49     logger.info(f'Running: {print_args}')
# ---> 51 process = subprocess.Popen(
#      52     args, stdout=subprocess.PIPE, stderr=subprocess.PIPE, **kwargs
#      53 )
#      54 stdout, stderr = process.communicate(timeout=timeout)
#      56 if stdout:
#
# File ~/.conda/envs/lanl_env/lib/python3.13/subprocess.py:1039, in Popen.__init__(self, args, bufsize, executable, stdin, stdout, stderr, preexec_fn, close_fds, shell, cwd, env, universal_newlines, startupinfo, creationflags, restore_signals, start_new_session, pass_fds, user, group, extra_groups, encoding, errors, text, umask, pipesize, process_group)
#    1035         if self.text_mode:
#    1036             self.stderr = io.TextIOWrapper(self.stderr,
#    1037                     encoding=encoding, errors=errors)
# -> 1039     self._execute_child(args, executable, preexec_fn, close_fds,
#    1040                         pass_fds, cwd, env,
#    1041                         startupinfo, creationflags, shell,
#    1042                         p2cread, p2cwrite,
#    1043                         c2pread, c2pwrite,
#    1044                         errread, errwrite,
#    1045                         restore_signals,
#    1046                         gid, gids, uid, umask,
#    1047                         start_new_session, process_group)
#    1048 except:
#    1049     # Cleanup if the child failed starting.
#    1050     for f in filter(None, (self.stdin, self.stdout, self.stderr)):
#
# File ~/.conda/envs/lanl_env/lib/python3.13/subprocess.py:1969, in Popen._execute_child(self, args, executable, preexec_fn, close_fds, pass_fds, cwd, env, startupinfo, creationflags, shell, p2cread, p2cwrite, c2pread, c2pwrite, errread, errwrite, restore_signals, gid, gids, uid, umask, start_new_session, process_group)
#    1967     err_msg = os.strerror(errno_num)
#    1968 if err_filename is not None:
# -> 1969     raise child_exception_type(errno_num, err_msg, err_filename)
#    1970 else:
#    1971     raise child_exception_type(errno_num, err_msg)
#
# FileNotFoundError: [Errno 2] No such file or directory: 'compute_mpas_region_masks'

# %%
bmm_filepath = '/pscratch/sd/b/bmoorema/run_001_062/'
ds = xr.open_dataset(bmm_filepath + '20210421_sim7_CORE_60to30E2r2.mpaso.hist.am.timeSeriesStatsMonthly.0063-09-01.nc')
# list(ds.keys())
# extract tracer and boundary forcing? flux terms
ds_fluxes = ds[['timeMonthly_avg_activeTracers_temperature','timeMonthly_avg_activeTracers_salinity','timeMonthly_avg_shortWaveHeatFlux', 
                'timeMonthly_avg_longWaveHeatFluxUp','timeMonthly_avg_longWaveHeatFluxDown','timeMonthly_avg_latentHeatFlux','timeMonthly_avg_sensibleHeatFlux','timeMonthly_avg_seaIceHeatFlux',
                'timeMonthly_avg_evaporationFlux','timeMonthly_avg_rainFlux','timeMonthly_avg_snowFlux','timeMonthly_avg_riverRunoffFlux','timeMonthly_avg_iceRunoffFlux',
                'timeMonthly_avg_seaIceFreshWaterFlux','timeMonthly_avg_seaIceSalinityFlux','timeMonthly_avg_salinitySurfaceRestoringTendency']]

# %%
list(ds.keys())
# Out:
# ['binBoundaryMerHeatTrans',
#  'binBoundaryMocStreamfunction',
#  'timeMonthly_counter',
#  'xtime_startMonthly',
#  'xtime_endMonthly',
#  'timeMonthly_avg_daysSinceStartOfSim',
#  'timeMonthly_avg_ssh',
#  'timeMonthly_avg_velocityMeridional',
#  'timeMonthly_avg_velocityZonal',
#  'timeMonthly_avg_layerThickness',
#  'timeMonthly_avg_density',
#  'timeMonthly_avg_potentialDensity',
#  'timeMonthly_avg_windStressZonal',
#  'timeMonthly_avg_windStressMeridional',
#  'timeMonthly_avg_frazilLayerThicknessTendency',
#  'timeMonthly_avg_meridionalHeatTransportLatZ',
#  'timeMonthly_avg_meridionalHeatTransportLat',
#  'timeMonthly_avg_tThreshMLD',
#  'timeMonthly_avg_dThreshMLD',
#  'timeMonthly_avg_normalVelocity',
#  'timeMonthly_avg_vertVelocityTop',
#  'timeMonthly_avg_zMid',
#  'timeMonthly_avg_atmosphericPressure',
#  'timeMonthly_avg_normalGMBolusVelocity',
#  'timeMonthly_avg_vertGMBolusVelocityTop',
#  'timeMonthly_avg_GMBolusVelocityZonal',
#  'timeMonthly_avg_GMBolusVelocityMeridional',
#  'timeMonthly_avg_cGMphaseSpeed',
#  'timeMonthly_avg_velocityZonalTimesTemperature_GM',
#  'timeMonthly_avg_velocityMeridionalTimesTemperature_GM',
#  'timeMonthly_avg_normalGMBolusVelocityTimesTemperature',
#  'timeMonthly_avg_normalGMBolusVelocitySquared',
#  'timeMonthly_avg_gmKappaScaling',
#  'timeMonthly_avg_gmBolusKappa',
#  'timeMonthly_avg_mocStreamvalLatAndDepthGM',
#  'timeMonthly_avg_mocStreamvalLatAndDepthRegionGM',
#  'timeMonthly_avg_penetrativeTemperatureFlux',
#  'timeMonthly_avg_latentHeatFlux',
#  'timeMonthly_avg_sensibleHeatFlux',
#  'timeMonthly_avg_longWaveHeatFluxUp',
#  'timeMonthly_avg_longWaveHeatFluxDown',
#  'timeMonthly_avg_seaIceHeatFlux',
#  'timeMonthly_avg_shortWaveHeatFlux',
#  'timeMonthly_avg_evaporationFlux',
#  'timeMonthly_avg_seaIceSalinityFlux',
#  'timeMonthly_avg_seaIceFreshWaterFlux',
#  'timeMonthly_avg_riverRunoffFlux',
#  'timeMonthly_avg_iceRunoffFlux',
#  'timeMonthly_avg_rainFlux',
#  'timeMonthly_avg_snowFlux',
#  'timeMonthly_avg_vertNonLocalFlux_vertNonLocalFluxTemp',
#  'timeMonthly_avg_bottomLayerShortwaveTemperatureFlux',
#  'timeMonthly_avg_salinitySurfaceRestoringTendency',
#  'timeMonthly_avg_areaCellGlobal',
#  'timeMonthly_avg_areaEdgeGlobal',
#  'timeMonthly_avg_areaTriangleGlobal',
#  'timeMonthly_avg_volumeCellGlobal',
#  'timeMonthly_avg_volumeEdgeGlobal',
#  'timeMonthly_avg_CFLNumberGlobal',
#  'timeMonthly_avg_vertDiffTopOfCell',
#  'timeMonthly_avg_vertViscTopOfCell',
#  'timeMonthly_avg_bulkRichardsonNumber',
#  'timeMonthly_avg_boundaryLayerDepth',
#  'timeMonthly_avg_columnIntegratedSpeed',
#  'timeMonthly_avg_mocStreamvalLatAndDepth',
#  'timeMonthly_avg_mocStreamvalLatAndDepthRegion',
#  'timeMonthly_avg_surfaceBuoyancyForcing',
#  'timeMonthly_avg_tendLayerThickness',
#  'timeMonthly_avg_boundaryLayerDepthSmooth',
#  'timeMonthly_avg_pressureAdjustedSSH',
#  'timeMonthly_avg_SSHSquared',
#  'timeMonthly_avg_velocityZonalSquared',
#  'timeMonthly_avg_velocityMeridionalSquared',
#  'timeMonthly_avg_normalVelocitySquared',
#  'timeMonthly_avg_velocityZonalTimesTemperature',
#  'timeMonthly_avg_velocityMeridionalTimesTemperature',
#  'timeMonthly_avg_normalVelocityTimesTemperature',
#  'timeMonthly_avg_oceanHeatContentSfcToBot',
#  'timeMonthly_avg_oceanHeatContentSfcTo700m',
#  'timeMonthly_avg_oceanHeatContent700mTo2000m',
#  'timeMonthly_avg_oceanHeatContent2000mToBot',
#  'timeMonthly_avg_activeTracerForcingMLTend_temperatureForcingMLTend',
#  'timeMonthly_avg_activeTracerForcingMLTend_salinityForcingMLTend',
#  'timeMonthly_avg_activeTracerHorMixMLTend_temperatureHorMixMLTend',
#  'timeMonthly_avg_activeTracerHorMixMLTend_salinityHorMixMLTend',
#  'timeMonthly_avg_activeTracerNonLocalMLTend_temperatureNonLocalMLTend',
#  'timeMonthly_avg_activeTracerNonLocalMLTend_salinityNonLocalMLTend',
#  'timeMonthly_avg_activeTracerVertAdvectionMLTend_temperatureVertAdvectionMLTend',
#  'timeMonthly_avg_activeTracerVertAdvectionMLTend_salinityVertAdvectionMLTend',
#  'timeMonthly_avg_activeTracerHorAdvectionMLTend_temperatureHorAdvectionMLTend',
#  'timeMonthly_avg_activeTracerHorAdvectionMLTend_salinityHorAdvectionMLTend',
#  'timeMonthly_avg_activeTracerVertMixMLTend_temperatureVertMixMLTend',
#  'timeMonthly_avg_activeTracerVertMixMLTend_salinityVertMixMLTend',
#  'timeMonthly_avg_activeTracersML_temperatureML',
#  'timeMonthly_avg_activeTracersML_salinityML',
#  'timeMonthly_avg_BruntVaisalaFreqTop',
#  'timeMonthly_avg_bruntVaisalaFreqML',
#  'timeMonthly_avg_activeTracersTendML_temperatureTendML',
#  'timeMonthly_avg_activeTracersTendML_salinityTendML',
#  'timeMonthly_avg_avgValueWithinOceanRegion_sumSurfaceMaskValue',
#  'timeMonthly_avg_avgValueWithinOceanRegion_avgSurfaceArea',
#  'timeMonthly_avg_avgValueWithinOceanRegion_avgLatentHeatFlux',
#  'timeMonthly_avg_avgValueWithinOceanRegion_avgSensibleHeatFlux',
#  'timeMonthly_avg_avgValueWithinOceanRegion_avgLongWaveHeatFluxUp',
#  'timeMonthly_avg_avgValueWithinOceanRegion_avgLongWaveHeatFluxDown',
#  'timeMonthly_avg_avgValueWithinOceanRegion_avgSeaIceHeatFlux',
#  'timeMonthly_avg_avgValueWithinOceanRegion_avgIcebergHeatFlux',
#  'timeMonthly_avg_avgValueWithinOceanRegion_avgShortWaveHeatFlux',
#  'timeMonthly_avg_avgValueWithinOceanRegion_avgEvaporationFlux',
#  'timeMonthly_avg_avgValueWithinOceanRegion_avgSeaIceFreshWaterFlux',
#  'timeMonthly_avg_avgValueWithinOceanRegion_avgIcebergFreshWaterFlux',
#  'timeMonthly_avg_avgValueWithinOceanRegion_avgRiverRunoffFlux',
#  'timeMonthly_avg_avgValueWithinOceanRegion_avgIceRunoffFlux',
#  'timeMonthly_avg_avgValueWithinOceanRegion_avgRainFlux',
#  'timeMonthly_avg_avgValueWithinOceanRegion_avgSnowFlux',
#  'timeMonthly_avg_avgValueWithinOceanRegion_avgSeaIceEnergy',
#  'timeMonthly_avg_avgValueWithinOceanRegion_avgSurfaceThicknessFlux',
#  'timeMonthly_avg_avgValueWithinOceanRegion_avgSurfaceTemperatureFlux',
#  'timeMonthly_avg_avgValueWithinOceanRegion_avgSurfaceSalinityFlux',
#  'timeMonthly_avg_avgValueWithinOceanRegion_avgSeaIceSalinityFlux',
#  'timeMonthly_avg_avgValueWithinOceanRegion_avgSurfaceWindStressMagnitude',
#  'timeMonthly_avg_avgValueWithinOceanRegion_avgWindStressZonal',
#  'timeMonthly_avg_avgValueWithinOceanRegion_avgWindStressMeridional',
#  'timeMonthly_avg_avgValueWithinOceanRegion_avgSeaSurfacePressure',
#  'timeMonthly_avg_avgValueWithinOceanRegion_avgSurfaceSSH',
#  'timeMonthly_avg_avgValueWithinOceanRegion_avgSurfaceTemperature',
#  'timeMonthly_avg_avgValueWithinOceanRegion_avgSurfaceSalinity',
#  'timeMonthly_avg_avgValueWithinOceanRegion_avgBoundaryLayerDepth',
#  'timeMonthly_avg_avgValueWithinOceanRegion_avgSurfaceNetHeatFlux',
#  'timeMonthly_avg_avgValueWithinOceanRegion_avgSurfaceNetSalinitFlux',
#  'timeMonthly_avg_avgValueWithinOceanRegion_avgSurfaceNetFreshWaterFlux',
#  'timeMonthly_avg_avgValueWithinOceanLayerRegion_sumLayerMaskValue',
#  'timeMonthly_avg_avgValueWithinOceanLayerRegion_avgLayerArea',
#  'timeMonthly_avg_avgValueWithinOceanLayerRegion_avgLayerThickness',
#  'timeMonthly_avg_avgValueWithinOceanLayerRegion_avgLayerDensity',
#  'timeMonthly_avg_avgValueWithinOceanLayerRegion_avgLayerPotentialDensity',
#  'timeMonthly_avg_avgValueWithinOceanLayerRegion_avgLayerBruntVaisalaFreqTop',
#  'timeMonthly_avg_avgValueWithinOceanLayerRegion_avgLayerVelocityZonal',
#  'timeMonthly_avg_avgValueWithinOceanLayerRegion_avgLayerVelocityMeridional',
#  'timeMonthly_avg_avgValueWithinOceanLayerRegion_avgLayerVertVelocityTop',
#  'timeMonthly_avg_avgValueWithinOceanLayerRegion_avgLayerTemperature',
#  'timeMonthly_avg_avgValueWithinOceanLayerRegion_avgLayerSalinity',
#  'timeMonthly_avg_avgValueWithinOceanLayerRegion_avgLayerKineticEnergyCell',
#  'timeMonthly_avg_avgValueWithinOceanLayerRegion_avgLayerRelativeVorticityCell',
#  'timeMonthly_avg_avgValueWithinOceanLayerRegion_avgLayerDivergence',
#  'timeMonthly_avg_avgValueWithinOceanLayerRegion_avgLayerRelativeEnstrophyCell',
#  'timeMonthly_avg_avgValueWithinOceanLayerRegion_avgLayerTemperatureHorAdv',
#  'timeMonthly_avg_avgValueWithinOceanLayerRegion_avgLayerSalinityHorAdv',
#  'timeMonthly_avg_avgValueWithinOceanLayerRegion_avgLayerTemperatureVertAdv',
#  'timeMonthly_avg_avgValueWithinOceanLayerRegion_avgLayerSalinityVertAdv',
#  'timeMonthly_avg_avgValueWithinOceanLayerRegion_avgLayerTemperatureSfcFlux',
#  'timeMonthly_avg_avgValueWithinOceanLayerRegion_avgLayerSalinitySfcFlux',
#  'timeMonthly_avg_avgValueWithinOceanLayerRegion_avgLayerTemperatureSW',
#  'timeMonthly_avg_avgValueWithinOceanLayerRegion_avgLayerTemperatureNL',
#  'timeMonthly_avg_avgValueWithinOceanLayerRegion_avgLayerSalinityNL',
#  'timeMonthly_avg_avgValueWithinOceanLayerRegion_avgLayerTemperatureVertMix',
#  'timeMonthly_avg_avgValueWithinOceanLayerRegion_avgLayerSalinityVertMix',
#  'timeMonthly_avg_avgValueWithinOceanVolumeRegion_sumVolumeMaskValue',
#  'timeMonthly_avg_avgValueWithinOceanVolumeRegion_avgVolumeArea',
#  'timeMonthly_avg_avgValueWithinOceanVolumeRegion_avgVolumeThickness',
#  'timeMonthly_avg_avgValueWithinOceanVolumeRegion_avgVolumeDensity',
#  'timeMonthly_avg_avgValueWithinOceanVolumeRegion_avgVolumePotentialDensity',
#  'timeMonthly_avg_avgValueWithinOceanVolumeRegion_avgVolumeBruntVaisalaFreqTop',
#  'timeMonthly_avg_avgValueWithinOceanVolumeRegion_avgVolumeVelocityZonal',
#  'timeMonthly_avg_avgValueWithinOceanVolumeRegion_avgVolumeVelocityMeridional',
#  'timeMonthly_avg_avgValueWithinOceanVolumeRegion_avgVolumeVertVelocityTop',
#  'timeMonthly_avg_avgValueWithinOceanVolumeRegion_avgVolumeTemperature',
#  'timeMonthly_avg_avgValueWithinOceanVolumeRegion_avgVolumeSalinity',
#  'timeMonthly_avg_avgValueWithinOceanVolumeRegion_avgVolumeKineticEnergyCell',
#  'timeMonthly_avg_avgValueWithinOceanVolumeRegion_avgVolumeRelativeVorticityCell',
#  'timeMonthly_avg_avgValueWithinOceanVolumeRegion_avgVolumeDivergence',
#  'timeMonthly_avg_avgValueWithinOceanVolumeRegion_avgVolumeRelativeEnstrophyCell',
#  'timeMonthly_avg_avgValueWithinOceanVolumeRegion_avgVolumeTemperatureHorAdv',
#  'timeMonthly_avg_avgValueWithinOceanVolumeRegion_avgVolumeSalinityHorAdv',
#  'timeMonthly_avg_avgValueWithinOceanVolumeRegion_avgVolumeTemperatureVertAdv',
#  'timeMonthly_avg_avgValueWithinOceanVolumeRegion_avgVolumeSalinityVertAdv',
#  'timeMonthly_avg_avgValueWithinOceanVolumeRegion_avgVolumeTemperatureSfcFlux',
#  'timeMonthly_avg_avgValueWithinOceanVolumeRegion_avgVolumeSalinitySfcFlux',
#  'timeMonthly_avg_avgValueWithinOceanVolumeRegion_avgVolumeTemperatureSW',
#  'timeMonthly_avg_avgValueWithinOceanVolumeRegion_avgVolumeTemperatureNL',
#  'timeMonthly_avg_avgValueWithinOceanVolumeRegion_avgVolumeSalinitySfcNL',
#  'timeMonthly_avg_avgValueWithinOceanVolumeRegion_avgVolumeTemperatureVertMix',
#  'timeMonthly_avg_avgValueWithinOceanVolumeRegion_avgVolumeSalinityVertMix',
#  'timeMonthly_avg_minGlobalStats_layerThicknessMin',
#  'timeMonthly_avg_minGlobalStats_normalVelocityMin',
#  'timeMonthly_avg_minGlobalStats_tangentialVelocityMin',
#  'timeMonthly_avg_minGlobalStats_layerThicknessEdgeMin',
#  'timeMonthly_avg_minGlobalStats_relativeVorticityMin',
#  'timeMonthly_avg_minGlobalStats_enstrophyMin',
#  'timeMonthly_avg_minGlobalStats_kineticEnergyCellMin',
#  'timeMonthly_avg_minGlobalStats_normalizedAbsoluteVorticityMin',
#  'timeMonthly_avg_minGlobalStats_pressureMin',
#  'timeMonthly_avg_minGlobalStats_montgomeryPotentialMin',
#  'timeMonthly_avg_minGlobalStats_vertVelocityTopMin',
#  'timeMonthly_avg_minGlobalStats_vertAleTransportTopMin',
#  'timeMonthly_avg_minGlobalStats_lowFreqDivergenceMin',
#  'timeMonthly_avg_minGlobalStats_highFreqThicknessMin',
#  'timeMonthly_avg_minGlobalStats_temperatureMin',
#  'timeMonthly_avg_minGlobalStats_salinityMin',
#  'timeMonthly_avg_minGlobalStats_layerThicknessPreviousTimestepMin',
#  'timeMonthly_avg_minGlobalStats_frazilLayerThicknessTendencyMin',
#  'timeMonthly_avg_minGlobalStats_evaporationFluxMin',
#  'timeMonthly_avg_minGlobalStats_rainFluxMin',
#  'timeMonthly_avg_minGlobalStats_snowFluxMin',
#  'timeMonthly_avg_minGlobalStats_seaIceFreshWaterFluxMin',
#  'timeMonthly_avg_minGlobalStats_icebergFreshWaterFluxMin',
#  'timeMonthly_avg_minGlobalStats_riverRunoffFluxMin',
#  'timeMonthly_avg_minGlobalStats_iceRunoffFluxMin',
#  'timeMonthly_avg_minGlobalStats_temperatureFluxMin',
#  'timeMonthly_avg_minGlobalStats_salinityFluxMin',
#  'timeMonthly_avg_minGlobalStats_salinityRestoringFluxMin',
#  'timeMonthly_avg_minGlobalStats_landIceFreshwaterFluxMin',
#  'timeMonthly_avg_minGlobalStats_accumulatedLandIceMassMin',
#  'timeMonthly_avg_minGlobalStats_accumulatedLandIceHeatMin',
#  'timeMonthly_avg_minGlobalStats_accumulatedLandIceFrazilMassMin',
#  'timeMonthly_avg_maxGlobalStats_layerThicknessMax',
#  'timeMonthly_avg_maxGlobalStats_normalVelocityMax',
#  'timeMonthly_avg_maxGlobalStats_tangentialVelocityMax',
#  'timeMonthly_avg_maxGlobalStats_layerThicknessEdgeMax',
#  'timeMonthly_avg_maxGlobalStats_relativeVorticityMax',
#  'timeMonthly_avg_maxGlobalStats_enstrophyMax',
#  'timeMonthly_avg_maxGlobalStats_kineticEnergyCellMax',
#  'timeMonthly_avg_maxGlobalStats_normalizedAbsoluteVorticityMax',
#  'timeMonthly_avg_maxGlobalStats_pressureMax',
#  'timeMonthly_avg_maxGlobalStats_montgomeryPotentialMax',
#  'timeMonthly_avg_maxGlobalStats_vertVelocityTopMax',
#  'timeMonthly_avg_maxGlobalStats_vertAleTransportTopMax',
#  'timeMonthly_avg_maxGlobalStats_lowFreqDivergenceMax',
#  'timeMonthly_avg_maxGlobalStats_highFreqThicknessMax',
#  'timeMonthly_avg_maxGlobalStats_temperatureMax',
#  'timeMonthly_avg_maxGlobalStats_salinityMax',
#  'timeMonthly_avg_maxGlobalStats_layerThicknessPreviousTimestepMax',
#  'timeMonthly_avg_maxGlobalStats_frazilLayerThicknessTendencyMax',
#  'timeMonthly_avg_maxGlobalStats_evaporationFluxMax',
#  'timeMonthly_avg_maxGlobalStats_rainFluxMax',
#  'timeMonthly_avg_maxGlobalStats_snowFluxMax',
#  'timeMonthly_avg_maxGlobalStats_seaIceFreshWaterFluxMax',
#  'timeMonthly_avg_maxGlobalStats_icebergFreshWaterFluxMax',
#  'timeMonthly_avg_maxGlobalStats_riverRunoffFluxMax',
#  'timeMonthly_avg_maxGlobalStats_iceRunoffFluxMax',
#  'timeMonthly_avg_maxGlobalStats_temperatureFluxMax',
#  'timeMonthly_avg_maxGlobalStats_salinityFluxMax',
#  'timeMonthly_avg_maxGlobalStats_salinityRestoringFluxMax',
#  'timeMonthly_avg_maxGlobalStats_landIceFreshwaterFluxMax',
#  'timeMonthly_avg_maxGlobalStats_accumulatedLandIceMassMax',
#  'timeMonthly_avg_maxGlobalStats_accumulatedLandIceHeatMax',
#  'timeMonthly_avg_maxGlobalStats_accumulatedLandIceFrazilMassMax',
#  'timeMonthly_avg_sumGlobalStats_layerThicknessSum',
#  'timeMonthly_avg_sumGlobalStats_normalVelocitySum',
#  'timeMonthly_avg_sumGlobalStats_tangentialVelocitySum',
#  'timeMonthly_avg_sumGlobalStats_layerThicknessEdgeSum',
#  'timeMonthly_avg_sumGlobalStats_relativeVorticitySum',
#  'timeMonthly_avg_sumGlobalStats_enstrophySum',
#  'timeMonthly_avg_sumGlobalStats_kineticEnergyCellSum',
#  'timeMonthly_avg_sumGlobalStats_normalizedAbsoluteVorticitySum',
#  'timeMonthly_avg_sumGlobalStats_pressureSum',
#  'timeMonthly_avg_sumGlobalStats_montgomeryPotentialSum',
#  'timeMonthly_avg_sumGlobalStats_vertVelocityTopSum',
#  'timeMonthly_avg_sumGlobalStats_vertAleTransportTopSum',
#  'timeMonthly_avg_sumGlobalStats_lowFreqDivergenceSum',
#  'timeMonthly_avg_sumGlobalStats_highFreqThicknessSum',
#  'timeMonthly_avg_sumGlobalStats_temperatureSum',
#  'timeMonthly_avg_sumGlobalStats_salinitySum',
#  'timeMonthly_avg_sumGlobalStats_layerThicknessPreviousTimestepSum',
#  'timeMonthly_avg_sumGlobalStats_frazilLayerThicknessTendencySum',
#  'timeMonthly_avg_sumGlobalStats_evaporationFluxSum',
#  'timeMonthly_avg_sumGlobalStats_rainFluxSum',
#  'timeMonthly_avg_sumGlobalStats_snowFluxSum',
#  'timeMonthly_avg_sumGlobalStats_seaIceFreshWaterFluxSum',
#  'timeMonthly_avg_sumGlobalStats_icebergFreshWaterFluxSum',
#  'timeMonthly_avg_sumGlobalStats_riverRunoffFluxSum',
#  'timeMonthly_avg_sumGlobalStats_iceRunoffFluxSum',
#  'timeMonthly_avg_sumGlobalStats_temperatureFluxSum',
#  'timeMonthly_avg_sumGlobalStats_salinityFluxSum',
#  'timeMonthly_avg_sumGlobalStats_salinityRestoringFluxSum',
#  'timeMonthly_avg_sumGlobalStats_landIceFreshwaterFluxSum',
#  'timeMonthly_avg_sumGlobalStats_accumulatedLandIceMassSum',
#  'timeMonthly_avg_sumGlobalStats_accumulatedLandIceHeatSum',
#  'timeMonthly_avg_sumGlobalStats_accumulatedLandIceFrazilMassSum',
#  'timeMonthly_avg_rmsGlobalStats_layerThicknessRms',
#  'timeMonthly_avg_rmsGlobalStats_normalVelocityRms',
#  'timeMonthly_avg_rmsGlobalStats_tangentialVelocityRms',
#  'timeMonthly_avg_rmsGlobalStats_layerThicknessEdgeRms',
#  'timeMonthly_avg_rmsGlobalStats_relativeVorticityRms',
#  'timeMonthly_avg_rmsGlobalStats_enstrophyRms',
#  'timeMonthly_avg_rmsGlobalStats_kineticEnergyCellRms',
#  'timeMonthly_avg_rmsGlobalStats_normalizedAbsoluteVorticityRms',
#  'timeMonthly_avg_rmsGlobalStats_pressureRms',
#  'timeMonthly_avg_rmsGlobalStats_montgomeryPotentialRms',
#  'timeMonthly_avg_rmsGlobalStats_vertVelocityTopRms',
#  'timeMonthly_avg_rmsGlobalStats_vertAleTransportTopRms',
#  'timeMonthly_avg_rmsGlobalStats_lowFreqDivergenceRms',
#  'timeMonthly_avg_rmsGlobalStats_highFreqThicknessRms',
#  'timeMonthly_avg_rmsGlobalStats_temperatureRms',
#  'timeMonthly_avg_rmsGlobalStats_salinityRms',
#  'timeMonthly_avg_rmsGlobalStats_layerThicknessPreviousTimestepRms',
#  'timeMonthly_avg_rmsGlobalStats_frazilLayerThicknessTendencyRms',
#  'timeMonthly_avg_rmsGlobalStats_evaporationFluxRms',
#  'timeMonthly_avg_rmsGlobalStats_rainFluxRms',
#  'timeMonthly_avg_rmsGlobalStats_snowFluxRms',
#  'timeMonthly_avg_rmsGlobalStats_seaIceFreshWaterFluxRms',
#  'timeMonthly_avg_rmsGlobalStats_icebergFreshWaterFluxRms',
#  'timeMonthly_avg_rmsGlobalStats_riverRunoffFluxRms',
#  'timeMonthly_avg_rmsGlobalStats_iceRunoffFluxRms',
#  'timeMonthly_avg_rmsGlobalStats_temperatureFluxRms',
#  'timeMonthly_avg_rmsGlobalStats_salinityFluxRms',
#  'timeMonthly_avg_rmsGlobalStats_salinityRestoringFluxRms',
#  'timeMonthly_avg_rmsGlobalStats_landIceFreshwaterFluxRms',
#  'timeMonthly_avg_rmsGlobalStats_accumulatedLandIceMassRms',
#  'timeMonthly_avg_rmsGlobalStats_accumulatedLandIceHeatRms',
#  'timeMonthly_avg_rmsGlobalStats_accumulatedLandIceFrazilMassRms',
#  'timeMonthly_avg_avgGlobalStats_layerThicknessAvg',
#  'timeMonthly_avg_avgGlobalStats_normalVelocityAvg',
#  'timeMonthly_avg_avgGlobalStats_tangentialVelocityAvg',
#  'timeMonthly_avg_avgGlobalStats_layerThicknessEdgeAvg',
#  'timeMonthly_avg_avgGlobalStats_relativeVorticityAvg',
#  'timeMonthly_avg_avgGlobalStats_enstrophyAvg',
#  'timeMonthly_avg_avgGlobalStats_kineticEnergyCellAvg',
#  'timeMonthly_avg_avgGlobalStats_normalizedAbsoluteVorticityAvg',
#  'timeMonthly_avg_avgGlobalStats_pressureAvg',
#  'timeMonthly_avg_avgGlobalStats_montgomeryPotentialAvg',
#  'timeMonthly_avg_avgGlobalStats_vertVelocityTopAvg',
#  'timeMonthly_avg_avgGlobalStats_vertAleTransportTopAvg',
#  'timeMonthly_avg_avgGlobalStats_lowFreqDivergenceAvg',
#  'timeMonthly_avg_avgGlobalStats_highFreqThicknessAvg',
#  'timeMonthly_avg_avgGlobalStats_temperatureAvg',
#  'timeMonthly_avg_avgGlobalStats_salinityAvg',
#  'timeMonthly_avg_avgGlobalStats_layerThicknessPreviousTimestepAvg',
#  'timeMonthly_avg_avgGlobalStats_frazilLayerThicknessTendencyAvg',
#  'timeMonthly_avg_avgGlobalStats_evaporationFluxAvg',
#  'timeMonthly_avg_avgGlobalStats_rainFluxAvg',
#  'timeMonthly_avg_avgGlobalStats_snowFluxAvg',
#  'timeMonthly_avg_avgGlobalStats_seaIceFreshWaterFluxAvg',
#  'timeMonthly_avg_avgGlobalStats_icebergFreshWaterFluxAvg',
#  'timeMonthly_avg_avgGlobalStats_riverRunoffFluxAvg',
#  'timeMonthly_avg_avgGlobalStats_iceRunoffFluxAvg',
#  'timeMonthly_avg_avgGlobalStats_temperatureFluxAvg',
#  'timeMonthly_avg_avgGlobalStats_salinityFluxAvg',
#  'timeMonthly_avg_avgGlobalStats_salinityRestoringFluxAvg',
#  'timeMonthly_avg_avgGlobalStats_landIceFreshwaterFluxAvg',
#  'timeMonthly_avg_avgGlobalStats_accumulatedLandIceMassAvg',
#  'timeMonthly_avg_avgGlobalStats_accumulatedLandIceHeatAvg',
#  'timeMonthly_avg_avgGlobalStats_accumulatedLandIceFrazilMassAvg',
#  'timeMonthly_avg_vertSumMinGlobalStats_layerThicknessMinVertSum',
#  'timeMonthly_avg_vertSumMinGlobalStats_normalVelocityMinVertSum',
#  'timeMonthly_avg_vertSumMinGlobalStats_tangentialVelocityMinVertSum',
#  'timeMonthly_avg_vertSumMinGlobalStats_layerThicknessEdgeMinVertSum',
#  'timeMonthly_avg_vertSumMinGlobalStats_relativeVorticityMinVertSum',
#  'timeMonthly_avg_vertSumMinGlobalStats_enstrophyMinVertSum',
#  'timeMonthly_avg_vertSumMinGlobalStats_kineticEnergyCellMinVertSum',
#  'timeMonthly_avg_vertSumMinGlobalStats_normalizedAbsoluteVorticityMinVertSum',
#  'timeMonthly_avg_vertSumMinGlobalStats_pressureMinVertSum',
#  'timeMonthly_avg_vertSumMinGlobalStats_montgomeryPotentialMinVertSum',
#  'timeMonthly_avg_vertSumMinGlobalStats_vertVelocityTopMinVertSum',
#  'timeMonthly_avg_vertSumMinGlobalStats_vertAleTransportTopMinVertSum',
#  'timeMonthly_avg_vertSumMinGlobalStats_lowFreqDivergenceMinVertSum',
#  'timeMonthly_avg_vertSumMinGlobalStats_highFreqThicknessMinVertSum',
#  'timeMonthly_avg_vertSumMinGlobalStats_temperatureMinVertSum',
#  'timeMonthly_avg_vertSumMinGlobalStats_salinityMinVertSum',
#  'timeMonthly_avg_vertSumMinGlobalStats_layerThicknessPreviousTimestepMinVertSum',
#  'timeMonthly_avg_vertSumMinGlobalStats_frazilLayerThicknessTendencyMinVertSum',
#  'timeMonthly_avg_vertSumMinGlobalStats_evaporationFluxMinVertSum',
#  'timeMonthly_avg_vertSumMinGlobalStats_rainFluxMinVertSum',
#  'timeMonthly_avg_vertSumMinGlobalStats_snowFluxMinVertSum',
#  'timeMonthly_avg_vertSumMinGlobalStats_seaIceFreshWaterFluxMinVertSum',
#  'timeMonthly_avg_vertSumMinGlobalStats_icebergFreshWaterFluxMinVertSum',
#  'timeMonthly_avg_vertSumMinGlobalStats_riverRunoffFluxMinVertSum',
#  'timeMonthly_avg_vertSumMinGlobalStats_iceRunoffFluxMinVertSum',
#  'timeMonthly_avg_vertSumMinGlobalStats_temperatureFluxMinVertSum',
#  'timeMonthly_avg_vertSumMinGlobalStats_salinityFluxMinVertSum',
#  'timeMonthly_avg_vertSumMinGlobalStats_salinityRestoringFluxMinVertSum',
#  'timeMonthly_avg_vertSumMinGlobalStats_landIceFreshwaterFluxMinVertSum',
#  'timeMonthly_avg_vertSumMinGlobalStats_accumulatedLandIceMassMinVertSum',
#  'timeMonthly_avg_vertSumMinGlobalStats_accumulatedLandIceHeatMinVertSum',
#  'timeMonthly_avg_vertSumMinGlobalStats_accumulatedLandIceFrazilMassMinVertSum',
#  'timeMonthly_avg_vertSumMaxGlobalStats_layerThicknessMaxVertSum',
#  'timeMonthly_avg_vertSumMaxGlobalStats_normalVelocityMaxVertSum',
#  'timeMonthly_avg_vertSumMaxGlobalStats_tangentialVelocityMaxVertSum',
#  'timeMonthly_avg_vertSumMaxGlobalStats_layerThicknessEdgeMaxVertSum',
#  'timeMonthly_avg_vertSumMaxGlobalStats_relativeVorticityMaxVertSum',
#  'timeMonthly_avg_vertSumMaxGlobalStats_enstrophyMaxVertSum',
#  'timeMonthly_avg_vertSumMaxGlobalStats_kineticEnergyCellMaxVertSum',
#  'timeMonthly_avg_vertSumMaxGlobalStats_normalizedAbsoluteVorticityMaxVertSum',
#  'timeMonthly_avg_vertSumMaxGlobalStats_pressureMaxVertSum',
#  'timeMonthly_avg_vertSumMaxGlobalStats_montgomeryPotentialMaxVertSum',
#  'timeMonthly_avg_vertSumMaxGlobalStats_vertVelocityTopMaxVertSum',
#  'timeMonthly_avg_vertSumMaxGlobalStats_vertAleTransportTopMaxVertSum',
#  'timeMonthly_avg_vertSumMaxGlobalStats_lowFreqDivergenceMaxVertSum',
#  'timeMonthly_avg_vertSumMaxGlobalStats_highFreqThicknessMaxVertSum',
#  'timeMonthly_avg_vertSumMaxGlobalStats_temperatureMaxVertSum',
#  'timeMonthly_avg_vertSumMaxGlobalStats_salinityMaxVertSum',
#  'timeMonthly_avg_vertSumMaxGlobalStats_layerThicknessPreviousTimestepMaxVertSum',
#  'timeMonthly_avg_vertSumMaxGlobalStats_frazilLayerThicknessTendencyMaxVertSum',
#  'timeMonthly_avg_vertSumMaxGlobalStats_evaporationFluxMaxVertSum',
#  'timeMonthly_avg_vertSumMaxGlobalStats_rainFluxMaxVertSum',
#  'timeMonthly_avg_vertSumMaxGlobalStats_snowFluxMaxVertSum',
#  'timeMonthly_avg_vertSumMaxGlobalStats_seaIceFreshWaterFluxMaxVertSum',
#  'timeMonthly_avg_vertSumMaxGlobalStats_icebergFreshWaterFluxMaxVertSum',
#  'timeMonthly_avg_vertSumMaxGlobalStats_riverRunoffFluxMaxVertSum',
#  'timeMonthly_avg_vertSumMaxGlobalStats_iceRunoffFluxMaxVertSum',
#  'timeMonthly_avg_vertSumMaxGlobalStats_temperatureFluxMaxVertSum',
#  'timeMonthly_avg_vertSumMaxGlobalStats_salinityFluxMaxVertSum',
#  'timeMonthly_avg_vertSumMaxGlobalStats_salinityRestoringFluxMaxVertSum',
#  'timeMonthly_avg_vertSumMaxGlobalStats_landIceFreshwaterFluxMaxVertSum',
#  'timeMonthly_avg_vertSumMaxGlobalStats_accumulatedLandIceMassMaxVertSum',
#  'timeMonthly_avg_vertSumMaxGlobalStats_accumulatedLandIceHeatMaxVertSum',
#  'timeMonthly_avg_vertSumMaxGlobalStats_accumulatedLandIceFrazilMassMaxVertSum',
#  'timeMonthly_avg_activeTracersTend_temperatureTend',
#  'timeMonthly_avg_activeTracersTend_salinityTend',
#  'timeMonthly_avg_activeTracerHorizontalAdvectionTendency_temperatureHorizontalAdvectionTendency',
#  'timeMonthly_avg_activeTracerHorizontalAdvectionTendency_salinityHorizontalAdvectionTendency',
#  'timeMonthly_avg_activeTracerVerticalAdvectionTendency_temperatureVerticalAdvectionTendency',
#  'timeMonthly_avg_activeTracerVerticalAdvectionTendency_salinityVerticalAdvectionTendency',
#  'timeMonthly_avg_activeTracerVertMixTendency_temperatureVertMixTendency',
#  'timeMonthly_avg_activeTracerVertMixTendency_salinityVertMixTendency',
#  'timeMonthly_avg_activeTracerHorMixTendency_temperatureHorMixTendency',
#  'timeMonthly_avg_activeTracerHorMixTendency_salinityHorMixTendency',
#  'timeMonthly_avg_activeTracerSurfaceFluxTendency_temperatureSurfaceFluxTendency',
#  'timeMonthly_avg_activeTracerSurfaceFluxTendency_salinitySurfaceFluxTendency',
#  'timeMonthly_avg_temperatureShortWaveTendency',
#  'timeMonthly_avg_activeTracerNonLocalTendency_temperatureNonLocalTendency',
#  'timeMonthly_avg_activeTracerNonLocalTendency_salinityNonLocalTendency',
#  'timeMonthly_avg_activeTracerVerticalAdvectionTopFlux_temperatureVerticalAdvectionTopFlux',
#  'timeMonthly_avg_activeTracerVerticalAdvectionTopFlux_salinityVerticalAdvectionTopFlux',
#  'timeMonthly_avg_activeTracerHorizontalAdvectionEdgeFlux_temperatureHorizontalAdvectionEdgeFlux',
#  'timeMonthly_avg_activeTracerHorizontalAdvectionEdgeFlux_salinityHorizontalAdvectionEdgeFlux',
#  'timeMonthly_avg_totalFreshWaterTemperatureFlux',
#  'timeMonthly_avg_activeTracers_temperature',
#  'timeMonthly_avg_activeTracers_salinity',
#  'timeMonthly_avg_activeTracersSurfaceFlux_temperatureSurfaceFlux',
#  'timeMonthly_avg_activeTracersSurfaceFlux_salinitySurfaceFlux',
#  'timeMonthly_avg_activeTracersSurfaceFluxRunoff_temperatureSurfaceFluxRunoff',
#  'timeMonthly_avg_activeTracersSurfaceFluxRunoff_salinitySurfaceFluxRunoff',
#  'timeMonthly_avg_activeTracersSurfaceFluxRemoved_temperatureSurfaceFluxRemoved',
#  'timeMonthly_avg_activeTracersSurfaceFluxRemoved_salinitySurfaceFluxRemoved',
#  'timeMonthly_avg_nonLocalSurfaceTracerFlux_nonLocalTemperatureSurfaceFlux',
#  'timeMonthly_avg_nonLocalSurfaceTracerFlux_nonLocalSalinitySurfaceFlux']

# %%
ds['timeMonthly_avg_activeTracersSurfaceFlux_temperatureSurfaceFlux']
# Out:
# <xarray.DataArray 'timeMonthly_avg_activeTracersSurfaceFlux_temperatureSurfaceFlux' (
#                                                                                      Time: 1,
#                                                                                      nCells: 236853)> Size: 947kB
# [236853 values with dtype=float32]
# Dimensions without coordinates: Time, nCells
# Attributes:
#     long_name:  Flux of temperature through the ocean surface. Positive into ...
#     units:      ^\circ C m s^{-1}
